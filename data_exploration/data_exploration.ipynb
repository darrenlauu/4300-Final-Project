# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import StrMethodFormatter

# %%
data_directory = 'data/'
df = pd.read_csv(data_directory + 'Hotel_Reviews.csv')
df_sample = df[:1000]
df_sample.to_csv('Hotel_Reviews_Sample', sep='\t')
df_sample
# Out:
#                                          Hotel_Address  \
# 0     s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 1     s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 2     s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 3     s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 4     s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# ..                                                 ...
# 995  1 2 Serjeant s Inn Fleet Street City of London...
# 996  1 2 Serjeant s Inn Fleet Street City of London...
# 997  1 2 Serjeant s Inn Fleet Street City of London...
# 998  1 2 Serjeant s Inn Fleet Street City of London...
# 999  1 2 Serjeant s Inn Fleet Street City of London...
#
#      Additional_Number_of_Scoring Review_Date  Average_Score  \
# 0                             194    8/3/2017            7.7
# 1                             194    8/3/2017            7.7
# 2                             194   7/31/2017            7.7
# ...

# %%
hotels = df.drop_duplicates(subset=['Hotel_Name'])
print('Number of hotels: {}'.format(len(hotels)))
ax = hotels.hist(column='Average_Score', bins=20, grid=False, figsize=(12,8), zorder=2, rwidth=0.9)
ax = ax[0]
for x in ax:

    # Despine
    x.spines['right'].set_visible(False)
    x.spines['top'].set_visible(False)
    x.spines['left'].set_visible(False)

    # Switch off ticks
    x.tick_params(axis="both", which="both", bottom="off", top="off", labelbottom="on", left="off", right="off", labelleft="on")

    # Draw horizontal axis lines
    vals = x.get_yticks()
    for tick in vals:
        x.axhline(y=tick, linestyle='dashed', alpha=0.4, color='#eeeeee', zorder=1)

    # Remove title
    x.set_title("")

    # Set x-axis label
    x.set_xlabel("Average Score", labelpad=20, weight='bold', size=12)

    # Set y-axis label
    x.set_ylabel("Frequency", labelpad=20, weight='bold', size=12)

    # Format y-axis label
    x.yaxis.set_major_formatter(StrMethodFormatter('{x:,g}'))
# Out:
# Number of hotels: 1492
